# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

import polars as pl
import pandas as pd
import numpy as np

# %%
bb_df = pd.read_csv('./data/bybit.csv')
gate_df = pd.read_csv('./data/gate.csv')

# %%
bb_df
# Out:
#    Contracts Trade Type     Qty  Entry Price  Realized P&L  Filled Price  \
# 0    AVLUSDT       SELL   20.00      0.39680     -0.607657       0.36720
# 1    AVLUSDT       SELL   50.00      0.39680     -1.513149       0.36732
# 2   AIOZUSDT        BUY   30.00      0.34930      0.044581       0.34660
# 3   AIOZUSDT        BUY   40.00      0.34930      0.043425       0.34700
# 4   AIOZUSDT        BUY   10.00      0.34930      0.010856       0.34700
# 5    XCHUSDT       SELL    1.78     16.79000     -0.433199      16.58000
# 6   AIOZUSDT        BUY   50.00      0.34944      0.098282       0.34700
# 7    REQUSDT        BUY  156.00      0.11744      0.012537       0.11720
# 8  KAITOUSDT        BUY   17.00      1.76810     -1.318808       1.82790
#
#   Exit Type Filled/Settlement Time(UTC+0)       Create Time
# 0     Trade              09:35 2025-03-06  09:35 2025-03-06
# 1     Trade              09:30 2025-03-06  09:30 2025-03-06
# ...

# %%
df['Realized P&L'].sum()
# Out:
# -3.6631299999999998

# %%
gate_df
# Out:
#       Contract            Order ID  Deal amount  Deal price   Role  \
# 0     AVL/USDT  216172782147156290            2     0.36710  taker
# 1     AVL/USDT  216172782147154992            5     0.36610  taker
# 2    AIOZ/USDT    7881299356359684           -3     0.34280  taker
# 3    AIOZ/USDT    7881299356359619           -4     0.34290  taker
# 4    AIOZ/USDT    7881299356359424           -1     0.34280  taker
# 5     XCH/USDT  200128708454973328           10    16.57000  taker
# 6     XCH/USDT  200128708454973328         1770    16.57400  taker
# 7     XCH/USDT  200128708454959167        -1127    16.78400  taker
# 8     XCH/USDT  200128708454959167         -653    16.79800  taker
# 9    AIOZ/USDT    7881299356326879            3     0.34730  taker
# 10   AIOZ/USDT    7881299356326879            5     0.34830  taker
# 11    AVL/USDT  216172782147065056           -7     0.39650  taker
# 12   AIOZ/USDT    7881299356323273           -5     0.34140  taker
# ...
